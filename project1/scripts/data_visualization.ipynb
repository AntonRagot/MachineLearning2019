# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from proj1_helpers import *
from implementations import *

# %%
DATA_TRAIN_PATH = '../data/train.csv'
data_train = pd.read_csv(DATA_TRAIN_PATH)
data_train.describe()
# Out:
#                   Id   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  250000.000000                250000.000000
# mean   224999.500000     -49.023079                    49.239819
# std     72168.927986     406.345647                    35.344886
# min    100000.000000    -999.000000                     0.000000
# 25%    162499.750000      78.100750                    19.241000
# 50%    224999.500000     105.012000                    46.524000
# 75%    287499.250000     130.606250                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000         250000.000000     250000.000000
# mean       81.181982      57.895962           -708.420675       -601.237051
# std        40.828691      63.655682            454.480565        657.972302
# ...

# %%
num_b = data_train.groupby(['Prediction']).count()['Id'][0]
num_s = data_train.groupby(['Prediction']).count()['Id'][1]

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'number of b', 'number of s'
sizes = [num_b, num_s]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
num_0 = data_train.groupby(['PRI_jet_num']).count()['Id'][0]
num_1 = data_train.groupby(['PRI_jet_num']).count()['Id'][1]
num_2 = data_train.groupby(['PRI_jet_num']).count()['Id'][2]
num_3 = data_train.groupby(['PRI_jet_num']).count()['Id'][3]
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'jet num 0', 'jet num 1', 'jet num 2', 'jet num 3'
sizes = [num_0, num_1, num_2, num_3]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## Ideas:
# - Replace value -999 by a mean of all the values of the concerned feature
